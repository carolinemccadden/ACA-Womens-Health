# %%
# By Caroline McCadden
# Importing numpy, pandas, and matplotlib
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Creating dataframe with health status data by sex for 2013-2019
# https://www.kff.org/other/state-indicator/percent-of-adults-reporting-fair-or-poor-health-by-sex/
status_df = pd.read_csv("~/Desktop/healthstatus19.csv", skiprows=2, usecols=['Location','All Adults','Male','Female'])
status_df['Year'] = 2019
df18 = pd.read_csv("~/Desktop/healthstatus18.csv", skiprows=2, usecols=['Location','All Adults','Male','Female'])
df18['Year'] = 2018
status_df = status_df.append(df18)
df17 = pd.read_csv("~/Desktop/healthstatus17.csv", skiprows=2, usecols=['Location','All Adults','Male','Female'])
df17['Year'] = 2017
status_df = status_df.append(df17)
df16 = pd.read_csv("~/Desktop/healthstatus16.csv", skiprows=2, usecols=['Location','All Adults','Male','Female'])
df16['Year'] = 2016
status_df = status_df.append(df16)
df15 = pd.read_csv("~/Desktop/healthstatus15.csv", skiprows=2, usecols=['Location','All Adults','Male','Female'])
df15['Year'] = 2015
status_df = status_df.append(df15)
df14 = pd.read_csv("~/Desktop/healthstatus14.csv", skiprows=2, usecols=['Location','All Adults','Male','Female'])
df14['Year'] = 2014
status_df = status_df.append(df14)
df13 = pd.read_csv("~/Desktop/healthstatus13.csv", skiprows=2, usecols=['Location','All Adults','Male','Female'])
df13['Year'] = 2013
status_df = status_df.append(df13)
status_df = status_df.dropna()

# %%
# Creating dataframe with healthcare coverage data by sex for 2008-2019
# https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-females/
# https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-males/
# Uploading all data for women first so I only have to set assign the sex feature once
coverage_df = pd.read_csv("~/Desktop/fcoverage19.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
coverage_df['Year'] = 2019
df18 = pd.read_csv("~/Desktop/fcoverage18.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df18['Year'] = 2018
coverage_df = coverage_df.append(df18)
df17 = pd.read_csv("~/Desktop/fcoverage17.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df17['Year'] = 2017
coverage_df = coverage_df.append(df17)
df16 = pd.read_csv("~/Desktop/fcoverage16.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df16['Year'] = 2016
coverage_df = coverage_df.append(df16)
df15 = pd.read_csv("~/Desktop/fcoverage15.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df15['Year'] = 2015
coverage_df = coverage_df.append(df15)
df14 = pd.read_csv("~/Desktop/fcoverage14.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df14['Year'] = 2014
coverage_df = coverage_df.append(df14)
df13 = pd.read_csv("~/Desktop/fcoverage13.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df13['Year'] = 2013
coverage_df = coverage_df.append(df13)
df12 = pd.read_csv("~/Desktop/fcoverage12.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df12['Year'] = 2012
coverage_df = coverage_df.append(df12)
df11 = pd.read_csv("~/Desktop/fcoverage11.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df11['Year'] = 2011
coverage_df = coverage_df.append(df11)
df10 = pd.read_csv("~/Desktop/fcoverage10.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df10['Year'] = 2010
coverage_df = coverage_df.append(df10)
df9 = pd.read_csv("~/Desktop/fcoverage9.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df9['Year'] = 2009
coverage_df = coverage_df.append(df9)
df8 = pd.read_csv("~/Desktop/fcoverage8.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df8['Year'] = 2008
coverage_df = coverage_df.append(df8)
coverage_df['Sex'] = 'Female'
# Uploading data for males
mcoverage_df = pd.read_csv("~/Desktop/mcoverage19.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
mcoverage_df['Year'] = 2019
df18 = pd.read_csv("~/Desktop/mcoverage18.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df18['Year'] = 2018
mcoverage_df = mcoverage_df.append(df18)
df17 = pd.read_csv("~/Desktop/mcoverage17.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df17['Year'] = 2017
mcoverage_df = mcoverage_df.append(df17)
df16 = pd.read_csv("~/Desktop/mcoverage16.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df16['Year'] = 2016
mcoverage_df = mcoverage_df.append(df16)
df15 = pd.read_csv("~/Desktop/mcoverage15.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df15['Year'] = 2015
mcoverage_df = mcoverage_df.append(df15)
df14 = pd.read_csv("~/Desktop/mcoverage14.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df14['Year'] = 2014
mcoverage_df = mcoverage_df.append(df14)
df13 = pd.read_csv("~/Desktop/mcoverage13.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df13['Year'] = 2013
mcoverage_df = mcoverage_df.append(df13)
df12 = pd.read_csv("~/Desktop/mcoverage12.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df12['Year'] = 2012
mcoverage_df = mcoverage_df.append(df12)
df11 = pd.read_csv("~/Desktop/mcoverage11.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df11['Year'] = 2011
mcoverage_df = mcoverage_df.append(df11)
df10 = pd.read_csv("~/Desktop/mcoverage10.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df10['Year'] = 2010
mcoverage_df = mcoverage_df.append(df10)
df9 = pd.read_csv("~/Desktop/mcoverage9.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df9['Year'] = 2009
mcoverage_df = mcoverage_df.append(df9)
df8 = pd.read_csv("~/Desktop/mcoverage8.csv", skiprows=2, usecols=['Location','Employer','Non-Group','Medicaid', 'Medicare','Military','Uninsured'])
df8['Year'] = 2008
mcoverage_df = mcoverage_df.append(df8)
mcoverage_df['Sex'] = 'Male'
# Combining data for females and males
coverage_df = coverage_df.append(mcoverage_df)
coverage_df = coverage_df.dropna()

# %%
# Creating dataframe with % of women who report having a pap smear in the past 3 (2016-2019) years and % who report
# not seeing a doctor in the past year (2019) due to cost
# https://www.kff.org/other/state-indicator/percent-of-women-ages-18-64-who-report-having-had-a-pap-smear-within-the-past-three-years-by-raceethnicity
# https://www.kff.org/womens-health-policy/state-indicator/females-who-did-not-see-a-doctor-in-the-past-12-months-due-to-cost-by-raceethnicity
care_df = pd.read_csv("~/Desktop/pap.csv", skiprows=2, nrows=54, usecols=['Location','All Women','Non-Hispanic White','Non-Hispanic Black', 'Hispanic','Asian and Native Hawaiian or Pacific Islander','American Indian/ Alaska Native','Other'])
care_df['Report'] = 'Pap Smear'
temp_df = pd.read_csv("~/Desktop/doctor.csv", skiprows=2, nrows=54, usecols=['Location','All Females', 'White',
                                                                   'Black', 'Hispanic','Asian and Native Hawaiian or Pacific Islander','American Indian/ Alaska Native','Other'])
temp_df = temp_df.rename(columns={'All Females': 'All Women', 'White': 'Non-Hispanic White', 'Black': 'Non-Hispanic Black'})
temp_df['Report'] = 'Doctor Visit'
care_df = care_df.append(temp_df)
care_df = care_df.replace(['NSD', np.nan])
care_df.to_csv(r'~/Desktop/testytest.csv', index = False)

# %%
# Creating dataframe with the teen birth rate per 1000 for 2013-2018
# https://www.kff.org/other/state-indicator/teen-birth-rate-per-1000/
birth_df = pd.read_csv("~/Desktop/birth18.csv", skiprows=2, usecols=['Location','Teen Birth Rate per 1,000'])
birth_df['Year'] = 2018
df17 = pd.read_csv("~/Desktop/birth17.csv", skiprows=2, usecols=['Location','Teen Birth Rate per 1,000'])
df17['Year'] = 2017
birth_df = birth_df.append(df17)
df16 = pd.read_csv("~/Desktop/birth16.csv", skiprows=2, usecols=['Location','Teen Birth Rate per 1,000'])
df16['Year'] = 2016
birth_df = birth_df.append(df16)
df15 = pd.read_csv("~/Desktop/birth15.csv", skiprows=2, usecols=['Location','Teen Birth Rate per 1,000'])
df15['Year'] = 2015
birth_df = birth_df.append(df15)
df14 = pd.read_csv("~/Desktop/birth14.csv", skiprows=2, usecols=['Location','Teen Birth Rate per 1,000'])
df14['Year'] = 2014
birth_df = birth_df.append(df14)
df13 = pd.read_csv("~/Desktop/birth13.csv", skiprows=2, usecols=['Location','Teen Birth Rate per 1,000'])
df13['Year'] = 2013
birth_df = birth_df.append(df13)
birth_df = birth_df.dropna()
